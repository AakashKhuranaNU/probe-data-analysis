# %%
import pandas as pd

# %%
column_names = ["linkPVID", "refNodeID", "nrefNodeID", "length", "functionalClass", "directionOfTravel", "speedCategory", "fromRefSpeedLimit", "toRefSpeedLimit", "fromRefNumLanes", "toRefNumLanes", "multiDigitized", "urban", "timeZone", "shapeInfo", "curvatureInfo", "slopeInfo"]
link_data = pd.read_csv("./probe_data_map_matching/Partition6467LinkData.csv", header=None, names=column_names)
link_data_shape = link_data.shape
print(link_data_shape)
# Out:
# (200089, 17)

# %%
link_data.head()
# Out:
#     linkPVID  refNodeID  nrefNodeID  length  functionalClass  \
# 0   62007637  162844982   162809070  335.04                5
# 1  567329767  162844982   162981512  134.56                5
# 2   62007648  162877732   162844982   97.01                5
# 3   78670326  162877732   163152693  314.84                5
# 4   51881672  174713859   174587951  110.17                3
#
#   directionOfTravel  speedCategory  fromRefSpeedLimit  toRefSpeedLimit  \
# 0                 B              7                 30               30
# 1                 B              7                  0                0
# 2                 B              7                 30               30
# 3                 B              7                 30               30
# 4                 B              6                 50               50
#
#    fromRefNumLanes  toRefNumLanes multiDigitized urban  timeZone  \
# 0                0              0              F     T       0.0
# ...

# %%
loi = link_data.iloc[[4]]
loi
# Out:
#    linkPVID  refNodeID  nrefNodeID  length  functionalClass directionOfTravel  \
# 4  51881672  174713859   174587951  110.17                3                 B
#
#    speedCategory  fromRefSpeedLimit  toRefSpeedLimit  fromRefNumLanes  \
# 4              6                 50               50                2
#
#    toRefNumLanes multiDigitized urban  timeZone  \
# 4              2              F     T       0.0
#
#                                            shapeInfo curvatureInfo  \
# 4  53.0643099/8.7903400/45.79|53.0650299/8.791470...           NaN
#
#                   slopeInfo
# 4  0.00/-0.090|110.17/0.062

# %%
shapeInfo = loi["shapeInfo"].to_string()
print(shapeInfo)
# Out:
# 4    53.0643099/8.7903400/45.79|53.0650299/8.791470...

# %%
column_names = ["linkPVID", "refNodeID", "nrefNodeID", "length", "functionalClass", "directionOfTravel", "speedCategory", "fromRefSpeedLimit", "toRefSpeedLimit", "fromRefNumLanes", "toRefNumLanes", "multiDigitized", "urban", "timeZone", "shapeInfo", "curvatureInfo", "slopeInfo"]
link_data = pd.read_csv("./probe_data_map_matching/Partition6467LinkData.csv", header=None, names=column_names)
link_data_shape = link_data.shape
print(link_data_shape)
